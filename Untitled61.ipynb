# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]

# %%
y=[2,4,1]

# %%
plt.plot(x,y)

# %%
plt.xlabel('x-axis')
# Out:
# Text(0.5, 0, 'x-axis')

# %%
plt.xlabel('y-axis')
# Out:
# Text(0.5, 0, 'y-axis')
